# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n=100000

results=random.rand(2,n)
hist(sum(results, axis=0),50)
# Out:
# (array([  114.,   260.,   433.,   573.,   762.,   896.,  1038.,  1219.,
#          1363.,  1452.,  1716.,  1839.,  1990.,  2198.,  2231.,  2473.,
#          2556.,  2763.,  2902.,  3086.,  3330.,  3446.,  3637.,  3780.,
#          3919.,  4005.,  3731.,  3553.,  3401.,  3104.,  3221.,  2883.,
#          2896.,  2604.,  2451.,  2358.,  2192.,  2045.,  1782.,  1689.,
#          1528.,  1299.,  1257.,  1055.,   936.,   698.,   575.,   421.,
#           260.,    80.]),
#  array([ 0.00510739,  0.0449466 ,  0.0847858 ,  0.12462501,  0.16446422,
#          0.20430343,  0.24414264,  0.28398185,  0.32382105,  0.36366026,
#          0.40349947,  0.44333868,  0.48317789,  0.52301709,  0.5628563 ,
#          0.60269551,  0.64253472,  0.68237393,  0.72221313,  0.76205234,
#          0.80189155,  0.84173076,  0.88156997,  0.92140918,  0.96124838,
#          1.00108759,  1.0409268 ,  1.08076601,  1.12060522,  1.16044442,
#          1.20028363,  1.24012284,  1.27996205,  1.31980126,  1.35964047,
#          1.39947967,  1.43931888,  1.47915809,  1.5189973 ,  1.55883651,
#          1.59867571,  1.63851492,  1.67835413,  1.71819334,  1.75803255,
#          1.79787175,  1.83771096,  1.87755017,  1.91738938,  1.95722859,
#          1.9970678 ]),
#  <a list of 50 Patch objects>)

# %%
results=random.rand(3,n)
hist(sum(results, axis=0),50)
# Out:
# (array([   24.,    52.,   118.,   193.,   284.,   403.,   530.,   731.,
#           954.,  1080.,  1293.,  1529.,  1729.,  2068.,  2349.,  2724.,
#          2989.,  3331.,  3637.,  3858.,  4097.,  4076.,  4308.,  4422.,
#          4415.,  4350.,  4351.,  4257.,  4112.,  3947.,  3741.,  3491.,
#          3212.,  2803.,  2423.,  2233.,  1973.,  1580.,  1387.,  1221.,
#           981.,   784.,   633.,   473.,   336.,   241.,   134.,    97.,
#            34.,    12.]),
#  array([ 0.05673435,  0.11503079,  0.17332723,  0.23162367,  0.28992011,
#          0.34821655,  0.40651299,  0.46480943,  0.52310587,  0.58140231,
#          0.63969875,  0.69799519,  0.75629163,  0.81458807,  0.87288451,
#          0.93118095,  0.98947739,  1.04777383,  1.10607027,  1.16436671,
#          1.22266315,  1.28095959,  1.33925603,  1.39755247,  1.45584891,
#          1.51414535,  1.57244179,  1.63073823,  1.68903467,  1.74733111,
#          1.80562755,  1.86392399,  1.92222043,  1.98051687,  2.03881331,
#          2.09710975,  2.15540619,  2.21370263,  2.27199907,  2.33029551,
#          2.38859195,  2.44688839,  2.50518483,  2.56348127,  2.62177771,
#          2.68007415,  2.73837059,  2.79666703,  2.85496347,  2.91325991,
#          2.97155635]),
#  <a list of 50 Patch objects>)

# %%
results=random.rand(4,n)
hist(sum(results, axis=0),50)
# Out:
# (array([  5.00000000e+00,   1.40000000e+01,   3.00000000e+01,
#           6.00000000e+01,   1.06000000e+02,   1.71000000e+02,
#           2.56000000e+02,   3.86000000e+02,   5.64000000e+02,
#           7.17000000e+02,   9.20000000e+02,   1.16100000e+03,
#           1.42500000e+03,   1.81200000e+03,   2.12800000e+03,
#           2.47100000e+03,   2.87100000e+03,   3.33200000e+03,
#           3.71900000e+03,   3.97500000e+03,   4.42000000e+03,
#           4.51000000e+03,   4.92900000e+03,   4.98700000e+03,
#           5.05400000e+03,   4.96000000e+03,   5.01900000e+03,
#           4.96300000e+03,   4.52300000e+03,   4.41900000e+03,
#           3.96500000e+03,   3.77800000e+03,   3.35000000e+03,
#           2.77500000e+03,   2.50400000e+03,   2.17000000e+03,
#           1.76500000e+03,   1.48800000e+03,   1.12900000e+03,
#           9.07000000e+02,   6.67000000e+02,   5.64000000e+02,
#           3.62000000e+02,   2.60000000e+02,   1.83000000e+02,
#           1.17000000e+02,   7.00000000e+01,   2.60000000e+01,
#           1.00000000e+01,   3.00000000e+00]),
#  array([ 0.09372209,  0.16988549,  0.24604889,  0.32221229,  0.3983757 ,
#          0.4745391 ,  0.5507025 ,  0.62686591,  0.70302931,  0.77919271,
#          0.85535611,  0.93151952,  1.00768292,  1.08384632,  1.16000972,
#          1.23617313,  1.31233653,  1.38849993,  1.46466334,  1.54082674,
#          1.61699014,  1.69315354,  1.76931695,  1.84548035,  1.92164375,
#          1.99780715,  2.07397056,  2.15013396,  2.22629736,  2.30246077,
#          2.37862417,  2.45478757,  2.53095097,  2.60711438,  2.68327778,
#          2.75944118,  2.83560458,  2.91176799,  2.98793139,  3.06409479,
#          3.1402582 ,  3.2164216 ,  3.292585  ,  3.3687484 ,  3.44491181,
#          3.52107521,  3.59723861,  3.67340201,  3.74956542,  3.82572882,
#          3.90189222]),
#  <a list of 50 Patch objects>)

# %%
results=random.rand(5,n)
hist(sum(results, axis=0),50)
# Out:
# (array([  1.00000000e+00,   4.00000000e+00,   9.00000000e+00,
#           1.60000000e+01,   3.30000000e+01,   6.40000000e+01,
#           1.24000000e+02,   1.99000000e+02,   3.02000000e+02,
#           3.93000000e+02,   6.00000000e+02,   8.50000000e+02,
#           1.08000000e+03,   1.43500000e+03,   1.81400000e+03,
#           2.19300000e+03,   2.65000000e+03,   3.08100000e+03,
#           3.54800000e+03,   3.96800000e+03,   4.34500000e+03,
#           4.78100000e+03,   5.15300000e+03,   5.30200000e+03,
#           5.48500000e+03,   5.53700000e+03,   5.46200000e+03,
#           5.28900000e+03,   5.13400000e+03,   4.73600000e+03,
#           4.45300000e+03,   3.87200000e+03,   3.52100000e+03,
#           2.96300000e+03,   2.61800000e+03,   2.19700000e+03,
#           1.75400000e+03,   1.42400000e+03,   1.05300000e+03,
#           8.37000000e+02,   5.96000000e+02,   3.98000000e+02,
#           2.96000000e+02,   1.99000000e+02,   1.04000000e+02,
#           6.40000000e+01,   4.00000000e+01,   1.40000000e+01,
#           5.00000000e+00,   4.00000000e+00]),
#  array([ 0.14693602,  0.2393784 ,  0.33182078,  0.42426316,  0.51670554,
#          0.60914792,  0.70159029,  0.79403267,  0.88647505,  0.97891743,
#          1.07135981,  1.16380219,  1.25624457,  1.34868694,  1.44112932,
#          1.5335717 ,  1.62601408,  1.71845646,  1.81089884,  1.90334122,
#          1.99578359,  2.08822597,  2.18066835,  2.27311073,  2.36555311,
#          2.45799549,  2.55043787,  2.64288024,  2.73532262,  2.827765  ,
#          2.92020738,  3.01264976,  3.10509214,  3.19753451,  3.28997689,
#          3.38241927,  3.47486165,  3.56730403,  3.65974641,  3.75218879,
#          3.84463116,  3.93707354,  4.02951592,  4.1219583 ,  4.21440068,
#          4.30684306,  4.39928544,  4.49172781,  4.58417019,  4.67661257,
#          4.76905495]),
#  <a list of 50 Patch objects>)

# %%
m=100
def random_sum(n,m):
    M=random.rand(n,m)
    return sum(M,axis=1)

M=random_sum(n,m)
hist(M,50)
# Out:
# (array([  1.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           4.00000000e+00,   5.00000000e+00,   8.00000000e+00,
#           2.70000000e+01,   4.70000000e+01,   8.20000000e+01,
#           1.32000000e+02,   2.23000000e+02,   2.99000000e+02,
#           4.95000000e+02,   7.51000000e+02,   1.03300000e+03,
#           1.43300000e+03,   1.94100000e+03,   2.56700000e+03,
#           3.24600000e+03,   3.86000000e+03,   4.62600000e+03,
#           5.58700000e+03,   6.09700000e+03,   6.39800000e+03,
#           6.85900000e+03,   6.80500000e+03,   7.02600000e+03,
#           6.66800000e+03,   6.16600000e+03,   5.48700000e+03,
#           4.86700000e+03,   4.05300000e+03,   3.40200000e+03,
#           2.71500000e+03,   2.11800000e+03,   1.59000000e+03,
#           1.15100000e+03,   7.89000000e+02,   5.67000000e+02,
#           3.51000000e+02,   2.08000000e+02,   1.38000000e+02,
#           7.60000000e+01,   4.40000000e+01,   2.70000000e+01,
#           1.30000000e+01,   7.00000000e+00,   5.00000000e+00,
#           0.00000000e+00,   5.00000000e+00]),
#  array([ 37.00658109,  37.5136083 ,  38.02063551,  38.52766272,
#          39.03468993,  39.54171715,  40.04874436,  40.55577157,
#          41.06279878,  41.56982599,  42.0768532 ,  42.58388041,
#          43.09090763,  43.59793484,  44.10496205,  44.61198926,
#          45.11901647,  45.62604368,  46.1330709 ,  46.64009811,
#          47.14712532,  47.65415253,  48.16117974,  48.66820695,
#          49.17523416,  49.68226138,  50.18928859,  50.6963158 ,
#          51.20334301,  51.71037022,  52.21739743,  52.72442465,
#          53.23145186,  53.73847907,  54.24550628,  54.75253349,
#          55.2595607 ,  55.76658791,  56.27361513,  56.78064234,
#          57.28766955,  57.79469676,  58.30172397,  58.80875118,
#          59.3157784 ,  59.82280561,  60.32983282,  60.83686003,
#          61.34388724,  61.85091445,  62.35794166]),
#  <a list of 50 Patch objects>)

# %%
for i in xrange(2,9):
    results=random.rand(i,n)
    totals=sum(results, axis=0)
    hist((totals-(i/2.)),bins=50, normed=True,histtype='step',label=str(i))
legend()

#Hint for exercise 5: center each plot about the same point by subtracting mean

# %%
u = random.rand(100000)
v = 2*u**(1./3)
hist(v, normed=True, bins=50, fc='c', label='v = g(u)')
x = linspace(0, 2, 400)
y = .375*x**2
plot(x, y, 'r', lw=2, label='p(v)')
xlabel('v')
legend(loc='upper left')

# %%
norm=random.normal(0,1,n)
hist(norm,normed=True, bins=50)
v=linspace(-5,5,n)
p=(1/sqrt(2*pi))*e**((-v**2)/2)
plot(v,p,'r')

# %%
#Stock Price Simulation
    #s(t) is price of stock at time t
    #model assumes underlying growth rate with random component
    #s(t+1)=(1+mu+sigma*epsilon)*s(t)
        #mu=growth rate
        #epsion=random component, normally distributed
        #sigma=volatility=amplitude of random component
        
def stock_sim(s_0,t,mu=0,sigma=0.05,trials=1):
    s=empty((trials,t))
    s[:,0]=s_0*ones(trials)
    for i in xrange(1,t):
        epsilon=random.normal(size=trials)
        s[:,i]=(1+mu+sigma*epsilon)*s[:,i-1]
    return s

# %%
s_0=1
mu=0.000
sigma=0.05
t_max=365
trials=10000
t=linspace(0,t_max,t_max)
s=stock_sim(s_0,t_max,mu,sigma,trials)

final_price=s[:,364]
hist(final_price,50)
EV=mean(final_price)
loss=final_price<1
p_loss=float(sum(loss))/trials
print "Expected Value =", EV
print "Probability of Losing Money =", p_loss
# Out:
# Expected Value = 1.00417850952
# Probability of Losing Money = 0.6846

# %%
s_0=1
mu=0
sigma=0.05
t_max=365
trials=5
t=linspace(0,t_max,t_max)
s=stock_sim(s_0,t_max,mu,sigma,trials)

for i in xrange(trials):
    plot(t,s[i,:])

# %%
#Golden Section Search
    #Start with an interval [a,b] which contains a minimum
    #let r=(sqrt(3)-1)/2
    #x1=a+(1-r)(b-a)
    #x2=a+r(b-a)
    #f1,f2=f(x1),f(x2)
    #Continue while (b-a)<tol
    #if f1<f2, a,x2,b=a,x1,x2
        #x1=a+(1-r)(b-a)
        #f1,f2=f(x1),f2
    #else, a,x1,b=x1,x2,b
        #x2=a+r(b-a)
        #f1,f2=f2,f(x2)
